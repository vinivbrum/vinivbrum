# %%
#importando as lib
import pandas as pd
# %matplotlib inline

# %%
#vamos fazer o carregamento do arquivo
df = pd.read_csv('cursos-prouni.csv')

# %%
df.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grau                  41447 non-null  object
#  1   turno                 41447 non-null  object
#  2   mensalidade           41447 non-null  float64
#  3   bolsa_integral_cotas  32520 non-null  float64
#  4   bolsa_integral_ampla  25404 non-null  float64
#  5   bolsa_parcial_cotas   8828 non-null   float64
#  6   bolsa_parcial_ampla   13041 non-null  float64
#  7   curso_id              41447 non-null  int64
#  8   curso_busca           41447 non-null  object
#  9   cidade_busca          41447 non-null  object
#  10  uf_busca              41447 non-null  object
#  11  cidade_filtro         41447 non-null  object
#  12  universidade_nome     41447 non-null  object
#  13  campus_nome           41447 non-null  object
#  14  campus_id             41447 non-null  int64
# ...

# %%
#qual curso com a mensalidade mais alta?
#vamos então fatiar o nosso dataframe onde o campo de mensalidade = maior mensalidade
df[df['mensalidade'] <= df['mensalidade'].max()].head(3000)[['universidade_nome','mensalidade','curso_busca','cidade_busca','uf_busca','nota_integral_ampla','nota_integral_cotas']]
# Out:
#                                      universidade_nome  mensalidade  \
# 0                    Universidade Anhanguera - UNIDERP      9999.99
# 1                    Faculdade Princesa do Oeste - FPO      9836.40
# 2            Universidade Cidade de São Paulo - UNICID      9715.61
# 3                    Faculdade Princesa do Oeste - FPO      9689.34
# 4                  Faculdade Barão do Rio Branco - FAB      9674.34
# ...                                                ...          ...
# 2995         Faculdade São Francisco de Assis - UNIFIN      1356.64
# 2996  Universidade do Oeste de Santa Catarina - UNOESC      1356.60
# 2997                   Universidade Salvador - UNIFACS      1356.50
# 2998                  Faculdade União de Goyazes - FUG      1356.40
# 2999  Universidade Presbiteriana Mackenzie - MACKENZIE      1356.00
#
#                   curso_busca  cidade_busca uf_busca  nota_integral_ampla  \
# 0                    Medicina  Campo Grande       MS               740.22
# ...

# %%
# e o mais barato?
df[df['mensalidade'] >= df['mensalidade'].min()].tail(30)
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 41417   Tecnológico  Curso a Distância        149.0                   0.0
# 41418   Tecnológico  Curso a Distância        149.0                   0.0
# 41419   Tecnológico  Curso a Distância        149.0                   0.0
# 41420   Tecnológico  Curso a Distância        149.0                   0.0
# 41421   Tecnológico  Curso a Distância        149.0                   0.0
# 41422   Tecnológico  Curso a Distância        149.0                   0.0
# 41423   Tecnológico  Curso a Distância        149.0                   0.0
# 41424   Tecnológico  Curso a Distância        149.0                   0.0
# 41425   Tecnológico  Curso a Distância        149.0                   0.0
# 41426   Tecnológico  Curso a Distância        149.0                   0.0
# 41427   Tecnológico  Curso a Distância        149.0                   0.0
# 41428   Tecnológico  Curso a Distância        149.0                   0.0
# ...

# %%
df_money[df_money['uf_busca']=="RS"].head(30)
# Out:
#                                      universidade_nome  mensalidade  \
# 18                 Universidade de Caxias do Sul - UCS      8329.95
# 50                         Faculdade Meridional - IMED      7560.00
# 53   Pontifícia Universidade Católica do Rio Grande...      7486.44
# 65             Universidade Luterana do Brasil - ULBRA      7340.03
# 78    Universidade do Vale do Rio dos Sinos - UNISINOS      7051.75
# 104          Universidade de Santa Cruz do Sul - UNISC      6470.30
# 112  Universidade Regional Integrada do Alto Urugua...      6252.54
# 124  Centro Universitário Franciscano - Unifra - UN...      5924.16
# 125           Universidade Católica de Pelotas - UCPEL      5919.17
# 135                     Universidade Feevale - FEEVALE      5547.77
# 170   Centro Universitário da Serra Gaúcha - Fsg - FSG      4069.54
# 172          Universidade de Santa Cruz do Sul - UNISC      3951.85
# 173  Pontifícia Universidade Católica do Rio Grande...      3938.70
# ...

# %%
df.loc[df.groupby('uf_busca')['mensalidade'].idxmax()][['universidade_nome','mensalidade','curso_busca','cidade_busca','uf_busca','nota_integral_ampla','nota_integral_cotas']]
# Out:
#                                       universidade_nome  mensalidade  \
# 4                   Faculdade Barão do Rio Branco - FAB      9674.34
# 67               Centro Universitário Tiradentes - FITS      7290.00
# 627                          Faculdade Uninassau Manaus      2127.05
# 202     Instituto Macapaense de Ensino Superior - IMMES      3607.62
# 9       Faculdade de Ciências Agrárias e da Saúde - FAS      9048.00
# 1                     Faculdade Princesa do Oeste - FPO      9836.40
# 92    Faculdades Integradas da União Educacional do ...      6757.92
# 118   Centro Universitário do Espírito Santo - Unesc...      6022.28
# 102   Pontifícia Universidade Católica de Goiás - PU...      6484.47
# 20          Universidade do Ceuma - Uniceuma - UNICEUMA      8281.38
# 7     Centro Universitário Presidente Tancredo de Al...      9350.00
# 0                     Universidade Anhanguera - UNIDERP      9999.99
# 8                   Universidade de Cuiabá - UNIC/UNIME      9208.00
# ...

# %%
categorias = ['universidade_nome','mensalidade','curso_busca','cidade_busca','uf_busca','nota_integral_ampla','nota_integral_cotas']

# %%
#Quem tem a maior nota de corte com cotas
df[df['nota_integral_ampla']<= df['nota_integral_ampla'].max()].head(20)[categorias]
# Out:
#                                     universidade_nome  mensalidade  \
# 0                   Universidade Anhanguera - UNIDERP      9999.99
# 1                   Faculdade Princesa do Oeste - FPO      9836.40
# 2           Universidade Cidade de São Paulo - UNICID      9715.61
# 3                   Faculdade Princesa do Oeste - FPO      9689.34
# 4                 Faculdade Barão do Rio Branco - FAB      9674.34
# 5            Universidade do Oeste Paulista - UNOESTE      9650.00
# 6                    Universidade de Marília - UNIMAR      9564.00
# 7   Centro Universitário Presidente Tancredo de Al...      9350.00
# 8                 Universidade de Cuiabá - UNIC/UNIME      9208.00
# 9     Faculdade de Ciências Agrárias e da Saúde - FAS      9048.00
# 10                   Faculdade Redentor - FACREDENTOR      9023.07
# 11                    Universidade Salvador - UNIFACS      8695.43
# 12  Claretiano - Faculdade - Claretianorc - CLARET...      8600.00
# ...

# %%
df.loc[df.groupby('uf_busca')['nota_integral_ampla'].idxmax()][categorias].sort_values(by=['nota_integral_ampla'],ascending=True)
# Out:
#                                        universidade_nome  mensalidade  \
# 12969  Centro Universitário Claretiano - Ceuclar - CE...       691.20
# 32690  Centro Universitário Leonardo da VInci - UNIAS...       273.00
# 1691    Centro de Ensino Superior do Amapá - Ceap - CEAP      1570.35
# 8                    Universidade de Cuiabá - UNIC/UNIME      9208.00
# 0                      Universidade Anhanguera - UNIDERP      9999.99
# 39     Centro Universitário Tocantinense Presidente A...      7793.50
# 99                           Universidade Potiguar - UNP      6505.09
# 108      Faculdades Integradas Aparício Carvalho - FIMCA      6340.26
# 67                Centro Universitário Tiradentes - FITS      7290.00
# 101                       Universidade Tiradentes - UNIT      6490.00
# 144                Faculdade Pernambucana de Saúde - FPS      5220.85
# 106              Universidade Católica de Brasília - UCB      6399.14
# ...

# %%
df.loc[df.groupby('curso_busca')['mensalidade'].idxmax()][categorias].head(50)
# Out:
#                                        universidade_nome  mensalidade  \
# 95                             Faculdade Dom Bosco - FDB      6552.52
# 9508   Centro Universitário Tabosa de Almeida - ASCES...       869.75
# 8622           Faculdades Integradas Pitágoras - FIP-MOC       919.00
# 15782               Universidade Nove de Julho - UNINOVE       579.00
# 13874  Faculdade de Ensino Superior de Marechal Cândi...       650.75
# 5408   Faculdade de Tecnologia La Salle - Estrela - F...      1112.91
# 603    Pontifícia Universidade Católica do Paraná - P...      2166.05
# 6987   Universidade Regional Integrada do Alto Urugua...      1000.48
# 7749            Universidade do Oeste Paulista - UNOESTE       966.33
# 377    Faculdade Anchieta de Ensino Superior do Paran...      2520.00
# 8223   Pontifícia Universidade Católica de Goiás - PU...       939.87
# 141                          Faculdade de Roseira - FARO      5367.60
# ...
